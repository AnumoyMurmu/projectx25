# %%
'''
   python library for data manipulation and analysis, 
   used for pre-processing of data such as data cleaning,
   built on top of numpy, provides data strcutures like series
    and dataframe, handles large datasets efficiently.
    easily intigrates with other python libs like matplotlib
    and seaborn.
 '''

# %%
import pandas as pd

# %%
''' 

key data structures in pandas
  1. series
  2. DataFrame

'''

# %%
''' 

 series - In Pandas, a Series is a one-dimensional labeled array capable 
 of holding data of any type (integers, strings, floating-point numbers, 
 Python objects, etc.). It is one of the fundamental data structures in Pandas 
 and can be thought of as a single column in a spreadsheet or a DataFrame. 

 '''

# %%
# series

s=pd.Series([1,2,3,4,5])

# %%
s

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

s

# %%
df=pd.DataFrame({'names':['axy','xcx','rqt'], 'marks':[22,45,56]})

df

# %%
''' 
A DataFrame is a two-dimensional, labeled data structure with columns of potentially different types, 
organized like a spreadsheet or an SQL table. It is a fundamental data structure used in data analysis 
for organizing and manipulating structured data, with common examples found in libraries like Pandas for Python. 

'''

# %%
# DataFrame

df=pd.read_csv('IPL Matches 2008-2020.csv')

df

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
# data selection

df['id']

# %%
type(df['id'])

# %%
df[['id','player_of_match']]

# %%
df.iloc[0]

# %%
df.isnull()

# %%
import numpy as np

# Create a sample DataFrame with null values
df2 = pd.DataFrame({
    'A': [1, 2, np.nan, 4],
    'B': [5, np.nan, 7, 8],
    'C': [9, 10, 11, np.nan]
})

# Check for null values in the entire DataFrame
print("DataFrame with boolean mask for null values:")
print(df2.isnull())

# %%
df2.dropna()

df2

# %%
df2.fillna(0, inplace=True)

df2

# %%
df.rename(columns={'player_of_match':'man_of_the_match'}, inplace=True)

# %%
df

# %%
df.info()

# %%
# convert 'date' column to pandas datetime (datetime64[ns]) to avoid NameError from missing pyarrow alias
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()

# %%
# adding a new column -zeros

df['zeros'] = [0 for i in range(len(df))]

df
