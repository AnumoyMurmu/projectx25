# %%
import pandas as pd

# %%
# converting the .json file into a pandas dataframe (df)

pd.read_json('train.json')

# %%
pd.read_json('train.json').info()

# %% [markdown]
# #### working with sql

# %%
pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("busielmorley/worldcities-pop-lang-rank-sql-create-tbls")

print("Path to dataset files:", path)

# %%
# %pip install mysql-connector-python

# %%
import mysql.connector
import pandas as pd

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="sql@123",
    database="world"
)

df = pd.read_sql("SELECT * FROM city LIMIT 10;", conn)
df.head()

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND'", conn)

# %%
pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy>60", conn)

# %%
df = pd.read_sql_query("SELECT * FROM city WHERE District LIKE 'West Bengali'", conn)

# %%
df

# %%
df.info()
