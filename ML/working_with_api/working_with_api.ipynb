# %%
'''
1. fetching data from any website's database
2. api - application programming interface
3. data pipelines, that helps data send from 
   point a to point b i.e supplying data from one app to
   another e.g uber fetching google maps for location
4. mmt use irctc api to let users know wheather a seat is 
   booked or not.
'''

# %%
print('hello worlf')
